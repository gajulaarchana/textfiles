# %%
import numpy as np 
import pandas as pd

# %%
data=pd.read_csv("C:/Users/vaishu/Documents/12.real state.csv")
data
# Out:
#                   street             city    zip state  beds  baths  sq__ft  \
# 0           3526 HIGH ST       SACRAMENTO  95838    CA     2      1     836
# 1            51 OMAHA CT       SACRAMENTO  95823    CA     3      1    1167
# 2         2796 BRANCH ST       SACRAMENTO  95815    CA     2      1     796
# 3       2805 JANETTE WAY       SACRAMENTO  95815    CA     2      1     852
# 4        6001 MCMAHON DR       SACRAMENTO  95824    CA     2      1     797
# ..                   ...              ...    ...   ...   ...    ...     ...
# 980   9169 GARLINGTON CT       SACRAMENTO  95829    CA     4      3    2280
# 981      6932 RUSKUT WAY       SACRAMENTO  95823    CA     3      2    1477
# 982    7933 DAFFODIL WAY   CITRUS HEIGHTS  95610    CA     3      2    1216
# 983     8304 RED FOX WAY        ELK GROVE  95758    CA     4      2    1685
# 984  3882 YELLOWSTONE LN  EL DORADO HILLS  95762    CA     3      2    1362
#
# ...

# %%
data.columns
# Out:
# Index(['street', 'city', 'zip', 'state', 'beds', 'baths', 'sq__ft', 'type',
#        'sale_date', 'price', 'latitude', 'longitude'],
#       dtype='object')

# %%
#Find	City wise list all the Villa which is not less than ten thousand.
filtered_villas = data[(data['type'] == 'villa') & (data['price'] >= 10000)]
city_villa_groups = filtered_villas.groupby('city')
for city, villas in city_villa_groups:
    print(f"City: {city}")
    for _, villa in villas.iterrows():
        print(f"Villa: {villa['street']} - Price: {villa['price']}")
    print("=" * 30)
# Out:
# City: ANTELOPE
# Villa: 8020 WALERGA RD - Price: 115000
# ...
# City: AUBURN
# Villa: 2231 COUNTRY VILLA CT - Price: 260000
# ...
# City: CAMERON PARK
# Villa: 3035 ESTEPA DR Unit 5C - Price: 119000
# ...
# City: CARMICHAEL
# Villa: 4010 ALEX LN - Price: 250134
# Villa: 7032 FAIR OAKS BLVD - Price: 139500
# Villa: 7110 STELLA LN Unit 15 - Price: 182000
# ...
# City: CITRUS HEIGHTS
# Villa: 6236 LONGFORD DR Unit 1 - Price: 116250
# Villa: 6272 LONGFORD DR Unit 1 - Price: 69000
# ...
# City: ELK GROVE
# Villa: 5201 LAGUNA OAKS DR Unit 140 - Price: 133000
# Villa: 5201 LAGUNA OAKS DR Unit 162 - Price: 141000
# Villa: 9512 EMERALD PARK DR Unit 3 - Price: 71000
# Villa: 5201 LAGUNA OAKS DR Unit 199 - Price: 98000
# Villa: 5201 LAGUNA OAKS DR Unit 172 - Price: 100000
# Villa: 5201 LAGUNA OAKS DR Unit 126 - Price: 145000
# ...
# City: FAIR OAKS
# Villa: 5333 PRIMROSE DR Unit 19A - Price: 142500
# ...
# City: FOLSOM
# Villa: 611 BLOSSOM ROCK LN - Price: 240000
# ...
# City: GOLD RIVER
# ...

# %%
#In GALT city which residential type has more than 800sq__ft. Display their respective details street,sq__ft,sale_date,city.
filtered_properties = data[(data['city'] == 'GALT') & (data['type'] == 'Residential') & (data['sq__ft'] > 800)]
for index, property_details in filtered_properties.iterrows():
    print("Street:", property_details['street'])
    print("Square Feet:", property_details['sq__ft'])
    print("Sale Date:", property_details['sale_date'])
    print("City:", property_details['city'])
# Out:
# Street: 1122 WILD POPPY CT
# Square Feet: 1406
# Sale Date: Wed May 21 00:00:00 EDT 2008
# City: GALT
# Street: 306 CAMELLIA WAY
# Square Feet: 1130
# Sale Date: Wed May 21 00:00:00 EDT 2008
# City: GALT
# Street: 404 6TH ST
# Square Feet: 1479
# Sale Date: Wed May 21 00:00:00 EDT 2008
# City: GALT
# Street: 1121 CREEKSIDE WAY
# Square Feet: 1080
# Sale Date: Tue May 20 00:00:00 EDT 2008
# City: GALT
# Street: 840 TRANQUIL LN
# Square Feet: 1266
# Sale Date: Tue May 20 00:00:00 EDT 2008
# City: GALT
# Street: 993 MANTON CT
# Square Feet: 2307
# Sale Date: Tue May 20 00:00:00 EDT 2008
# City: GALT
# Street: 796 BUTTERCUP CIR
# Square Feet: 2159
# Sale Date: Tue May 20 00:00:00 EDT 2008
# City: GALT
# Street: 1092 MAUGHAM CT
# Square Feet: 3746
# Sale Date: Tue May 20 00:00:00 EDT 2008
# City: GALT
# Street: 201 CARLO CT
# Square Feet: 1080
# Sale Date: Mon May 19 00:00:00 EDT 2008
# City: GALT
# Street: 746 MOOSE CREEK WAY
# Square Feet: 1100
# Sale Date: Mon May 19 00:00:00 EDT 2008
# ...

# %%
#Which is the cheapest Villa in CA. name the city,street and price for the Villa
cheapest_villa = data[(data['state'] == 'CA') & (data['type'] == 'villa')].sort_values(by='price').iloc[0]
print("City:", cheapest_villa['city'])
print("Street:", cheapest_villa['street'])
print("Price:", cheapest_villa['price'])
# Out:
# City: SACRAMENTO
# Street: 5840 WALERGA RD
# Price: 40000

# %%
#List top 5 residency details which lie in the budget of 60000-120000, an area more than 1450, min bedroom 3 and, min bathroom 2.
top_5_properties = data.copy()
filtered_properties = top_5_properties.query(
    "60000 <= price <= 120000 and sq__ft > 1450 and beds >= 3 and baths >= 2"
)
print(filtered_properties.head(5))
# Out:
#            street        city    zip state  beds  baths  sq__ft          type  \
# 366  7342 GIGI PL  SACRAMENTO  95828    CA     4      4    1995  Multi-Family
#
#                         sale_date   price   latitude   longitude
# 366  Mon May 19 00:00:00 EDT 2008  120000  38.490704 -121.410176
